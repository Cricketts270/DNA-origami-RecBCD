# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go 
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mpl_toolkits.mplot3d.art3d import Line3DCollection
import plotly.graph_objects as go
from ipynb.fs.full.function import display_trajectory
from matplotlib import ticker
import math


filename="RecBCD_plain2.csv"
pixel_size= 154 #in nanometers (value only)
time_step= 20   #in miliseconds (value only)
frame_start= 300  #enter 0 to start from beginning    
frame_end = 700#enter -1 for full data set
bin_size = 1       #bin size for downsampling/filter
processing = "none"  #enter downsample, filter, or none
graph_type = "3D"  #enter 3D, 2D, interactive 
title = "RecBCD Activity"
X_axis_label = "X pixel displacement"
Y_axis_label = "Y pixel displacement"
Z_axis_label = "Time (ms)"
x_unit = 3 #3 for pixel 5 for nm
y_unit = 4 # 4 for pixel 6 for nm

graph = display_trajectory(filename, pixel_size, time_step, frame_start, frame_end, bin_size, processing, graph_type, title, X_axis_label, Y_axis_label, Z_axis_label, x_unit, y_unit)
graph
# Out:
# filename: RecBCD_plain2.csv    |  pixel_size: 154  |  time_step: 20
# frame_start: 300  |    frame_end: 700  |  bin_size: 1
# processing: none  |  graph_type: 3D  |  title: RecBCD Activity
# X_axis_label: X pixel displacement  |  Y_axis_label: Y pixel displacement  |  Z_axis_label: Time (ms)
